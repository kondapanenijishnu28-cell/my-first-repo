# %% [markdown]
# The difference between hardware and software is that hardware refers to the physical components of a computer, while software refers to the programs and operating systems that run on the computer.Hardware Example: CPU (Central Processing Unit)Software Example: Windows Operating System
